# %% [markdown]
# # List comprehension
#
# List comprehension is a concise way of creating a new list from an existing iterable.  It helps you write clean, readable and efficient code compared to traditional loops.

# %% [markdown]
# Suppose you wish to return a new list where every number is squared:

# %%
a = [2,3,4,5]
squared = [val**2 for val in a]
print(squared)
# Out:
# [4, 9]
