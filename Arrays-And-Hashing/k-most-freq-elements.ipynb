# %% [markdown]
# # K Most Frequent Elements Algorithm

# %%
def k_most_freq_elements(nums):
    freq = defaultdict(int)
    for n in nums:
        if n not in freq:
            freq[n] = 0
        freq[n]+=1
    items = freq.items()
    items.sort(reverse= True, key = lambda x: x[1])
    return [x[0] for x in items[:k]]
