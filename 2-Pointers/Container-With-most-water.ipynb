# %%
def maxArea(self, height):
    """
    Question 1
    How is the water calculated ?

    Smallest of the two heights * right index - left index
    (i, height)
    left = (1, 8)
    right = (8, 7)
    area = 7 * (8 - 1) = 7 * 7 = 49

    Question 2
    when do we move the left and right pointers
    """
    left = 0
    right = len(height) - 1
    max_area = 0

    if len(height) == 2:
        return min(height[left],height[right]) * 1

    # Move the pointer with the smallest value until they meet
    while left < right:
        max_area = max(max_area, min(height[left],height[right]) * (right - left))
        if height[left] <= height[right]:
            left += 1
        elif height[right] < height[left]:
            right -= 1
    return max_area
